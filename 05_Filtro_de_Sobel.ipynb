# %% [markdown]
# <a href="https://colab.research.google.com/github/dilia-w/Visao-Computacional/blob/main/05_Filtro_de_Sobel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

imagem = np.zeros((256, 256), dtype=np.uint8)
x1, y1 = 64, 64
x2, y2 = 192, 192
imagem[y1:y2, x1:x2] = 255

sobel_x = cv2.Sobel(imagem, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(imagem, cv2.CV_64F, 0, 1, ksize=3)
sobel_xy = cv2.Sobel(imagem, cv2.CV_64F, 1, 1, ksize=3)

sobel_x = cv2.convertScaleAbs(sobel_x)
sobel_y = cv2.convertScaleAbs(sobel_y)
sobel_xy = cv2.convertScaleAbs(sobel_xy)

plt.figure(figsize=(6.4, 7))

plt.subplot(2, 2, 1)
plt.imshow(imagem, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(sobel_x, cmap='gray')
plt.title('Bordas Verticais (Sobel)')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(sobel_xy, cmap='gray')
plt.title('Derivando X e Y')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(sobel_y, cmap='gray')
plt.title('Bordas Horizontais (Sobel)')
plt.axis('off')

plt.tight_layout()
plt.show()
