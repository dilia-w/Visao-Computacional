# %% [markdown]
# <a href="https://colab.research.google.com/github/dilia-w/Visao-Computacional/blob/main/04_Detector_de_bordas_e_de_dire%C3%A7%C3%A3o_das_bordas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

imagem = np.zeros((256, 256), dtype=np.uint8)
x1, y1 = 64, 64
x2, y2 = 192, 192
imagem[y1:y2, x1:x2] = 255

filtro = np.array([[ -3-3j, 0-10j,  +3-3j],
                   [-10+0j, 0+0j, +10+0j],
                   [ -3+3j, 0+10j,  +3+3j]])

imagem_filtrada3 = signal.convolve2d(imagem, filtro, 'valid')

plt.figure(figsize=(6.4, 7))

plt.subplot(2, 2, 1)
plt.imshow(imagem, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.absolute(imagem_filtrada3), cmap='gray')
plt.title('Bordas')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(np.angle(imagem_filtrada3), cmap='hsv')
plt.title('Direção das Bordas')
plt.axis('off')

plt.tight_layout()
plt.show()
