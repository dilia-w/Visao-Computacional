# %% [markdown]
# <a href="https://colab.research.google.com/github/dilia-w/Visao-Computacional/blob/main/09_Calculando_a_tranformada_de_Fourier_de_uma_imagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.fft import fft2, fftshift

# Criando uma matriz de zeros
image = np.zeros((256, 256), dtype=np.uint8)

# Indicando um intervalo de Pixels
x1, y1 = 64, 64
x2, y2 = 192, 192

# Convertendo o intervalo de valores da matriz de 0 para 255
image[y1:y2, x1:x2] = 255

# Calculando a transformada de Fourier da imagem (FFT 2D)
transformada = fft2(image)

# Apresentando a imagem e a sua transformada de Fourier
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(np.abs(transformada), cmap='gray')
plt.title('Transformada de Fourier')
plt.axis('off')

plt.tight_layout()
plt.show()
