# %% [markdown]
# <a href="https://colab.research.google.com/github/dilia-w/Visao-Computacional/blob/main/07_Detector_de_quinas_de_Harris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

imagem = np.zeros((256, 256), dtype=np.uint8)
x1, y1 = 64, 64
x2, y2 = 192, 192
imagem[y1:y2, x1:x2] = 255

imagem_harris = np.float32(imagem)
dst = cv2.cornerHarris(imagem_harris, blockSize=3, ksize=3, k=0.04)
dst = cv2.dilate(dst, None)

imagem_harris[dst > 0.01 * dst.max()] = 255

plt.figure(figsize=(6.4, 7))

plt.subplot(2, 2, 1)
plt.imshow(imagem, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(imagem_harris, cmap='gray')
plt.title('Imagem com Pontos de Interesse Harris')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(dst, cmap='gray')
plt.title('Pontos de Interesse Harris')
plt.axis('off')

plt.tight_layout()
plt.show()
