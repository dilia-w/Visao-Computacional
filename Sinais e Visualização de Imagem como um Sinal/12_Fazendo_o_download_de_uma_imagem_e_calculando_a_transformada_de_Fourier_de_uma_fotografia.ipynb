# %% [markdown]
# <a href="https://colab.research.google.com/github/dilia-w/Visao-Computacional/blob/main/12_Fazendo_o_download_de_uma_imagem_e_calculando_a_transformada_de_Fourier_de_uma_fotografia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import urllib.request
import cv2
import matplotlib.pyplot as plt
from scipy.fft import fft2, fftshift

# Fazendo o download da imagem de Lena
image_url = 'https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png'
urllib.request.urlretrieve(image_url, 'lena_gray.png')

# Lendo a imagem em escala de cinza
image = cv2.imread('lena_gray.png', cv2.IMREAD_GRAYSCALE)

# Calculando a transformada de Fourier 2D da imagem
transformada = fftshift(fft2(image))

# Apresentando a imagem e a sua transformada de Fourier
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(np.log(1 + np.abs(transformada)), cmap='gray')
plt.title('Transformada de Fourier')
plt.axis('off')

plt.tight_layout()
plt.show()
